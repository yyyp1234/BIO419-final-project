# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2=pd.read_excel('Data2.xlsx')

# %%
df2
# Out:
#         Year  Relationship
# 0       1980  Acquaintance
# 1       1980  Acquaintance
# 2       1980       Unknown
# 3       1980  Acquaintance
# 4       1980       Unknown
# 5       1980  Acquaintance
# 6       1980          Wife
# 7       1980          Wife
# 8       1980       Unknown
# 9       1980       Unknown
# 10      1980       Unknown
# 11      1980      Stranger
# 12      1980    Girlfriend
# 13      1980       Unknown
# 14      1980       Unknown
# 15      1980    Ex-Husband
# 16      1980  Acquaintance
# 17      1980       Brother
# 18      1980  Acquaintance
# 19      1980       Brother
# 20      1980  Stepdaughter
# 21      1980  Stepdaughter
# 22      1980  Acquaintance
# 23      1980          Wife
# 24      1980  Stepdaughter
# 25      1980          Wife
# 26      1980       Unknown
# 27      1980       Husband
# 28      1980       Brother
# 29      1980       Unknown
# ...      ...           ...
# 638424  2014       Husband
# 638425  2014          Wife
# 638426  2014  Acquaintance
# 638427  2014  Acquaintance
# 638428  2014      Stranger
# 638429  2014      Stranger
# 638430  2014  Acquaintance
# 638431  2014        Family
# 638432  2014  Acquaintance
# 638433  2014        Friend
# 638434  2014       Unknown
# 638435  2014       Unknown
# 638436  2014       Unknown
# 638437  2014  Acquaintance
# 638438  2014  Acquaintance
# 638439  2014  Acquaintance
# 638440  2014      Stranger
# 638441  2014  Acquaintance
# 638442  2014          Wife
# 638443  2014  Acquaintance
# 638444  2014  Acquaintance
# 638445  2014  Acquaintance
# 638446  2014        Mother
# 638447  2014    Girlfriend
# 638448  2014        Friend
# 638449  2014       Unknown
# 638450  2014  Acquaintance
# 638451  2014      Daughter
# 638452  2014      Stranger
# 638453  2014      Daughter
#
# [638454 rows x 2 columns]

# %%
df2.Relationship.unique()
# Out:
# array(['Acquaintance', 'Unknown', 'Wife', 'Stranger', 'Girlfriend',
#        'Ex-Husband', 'Brother', 'Stepdaughter', 'Husband', 'Sister',
#        'Friend', 'Family', 'Neighbor', 'Father', 'In-Law', 'Son',
#        'Ex-Wife', 'Boyfriend', 'Mother', 'Common-Law Husband',
#        'Common-Law Wife', 'Stepfather', 'Stepson', 'Stepmother',
#        'Daughter', 'Boyfriend/Girlfriend', 'Employer', 'Employee'], dtype=object)

# %%
df2['Relationship'] = df2['Relationship'].map({'Acquaintance': 1, 'Unknown': 2,'Wife': 3, 'Stranger': 4, 'Girlfriend': 5,
       'Ex-Husband': 6, 'Brother': 7, 'Stepdaughter': 8, 'Husband': 9, 'Sister': 10,
       'Friend': 11, 'Family': 12, 'Neighbor': 13, 'Father': 14, 'In-Law': 15, 'Son': 16,
       'Ex-Wife': 17, 'Boyfriend': 18, 'Mother': 19, 'Common-Law Husband': 20,
       'Common-Law Wife': 21, 'Stepfather': 22, 'Stepson': 23, 'Stepmother': 24,
       'Daughter': 25, 'Boyfriend/Girlfriend': 26, 'Employer': 27, 'Employee': 28})

# %%
df2
# Out:
#         Year  Relationship
# 0       1980             1
# 1       1980             1
# 2       1980             2
# 3       1980             1
# 4       1980             2
# 5       1980             1
# 6       1980             3
# 7       1980             3
# 8       1980             2
# 9       1980             2
# 10      1980             2
# 11      1980             4
# 12      1980             5
# 13      1980             2
# 14      1980             2
# 15      1980             6
# 16      1980             1
# 17      1980             7
# 18      1980             1
# 19      1980             7
# 20      1980             8
# 21      1980             8
# 22      1980             1
# 23      1980             3
# 24      1980             8
# 25      1980             3
# 26      1980             2
# 27      1980             9
# 28      1980             7
# 29      1980             2
# ...      ...           ...
# 638424  2014             9
# 638425  2014             3
# 638426  2014             1
# 638427  2014             1
# 638428  2014             4
# 638429  2014             4
# 638430  2014             1
# 638431  2014            12
# 638432  2014             1
# 638433  2014            11
# 638434  2014             2
# 638435  2014             2
# 638436  2014             2
# 638437  2014             1
# 638438  2014             1
# 638439  2014             1
# 638440  2014             4
# 638441  2014             1
# 638442  2014             3
# 638443  2014             1
# 638444  2014             1
# 638445  2014             1
# 638446  2014            19
# 638447  2014             5
# 638448  2014            11
# 638449  2014             2
# 638450  2014             1
# 638451  2014            25
# 638452  2014             4
# 638453  2014            25
#
# [638454 rows x 2 columns]

# %%
Relationship_array = np.array (df2[['Relationship']]).T
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
count10 = 0
count11 = 0
count12 = 0
count13 = 0
count14 = 0
count15 = 0
count16 = 0
count17 = 0
count18 = 0
count19 = 0
count20 = 0
count21 = 0
count22 = 0
count23 = 0
count24 = 0
count25 = 0
count26 = 0
count27 = 0
count28 = 0

for i in np.nditer(Relationship_array): 
    if i == 1:
        count1+=1 
    if i ==2:
        count2+=1 
    if i == 3:
        count3+=1
    if i == 4:
        count4+=1
    if i == 5:
        count5+=1
    if i == 6:
        count6+=1
    if i == 7:
        count7+=1
    if i == 8:
        count8+=1
    if i == 9:
        count9+=1
    if i == 10:
        count10+=1
    if i == 11:
        count11+=1
    if i == 12:
        count12+=1
    if i == 13:
        count13+=1
    if i == 14:
        count14+=1
    if i == 15:
        count15+=1
    if i == 16:
        count16+=1
    if i == 17:
        count17+=1
    if i == 18:
        count18+=1
    if i == 19:
        count19+=1
    if i == 20:
        count20+=1
    if i == 21:
        count21+=1
    if i == 22:
        count22+=1
    if i == 23:
        count23+=1
    if i == 24:
        count24+=1
    if i == 25:
        count25+=1
    if i == 26:
        count26+=1
    if i == 27:
        count27+=1
    if i == 28:
        count28+=1

# %%
print ('Acquaintance', count1,
       'Unknown', count2,
       'Wife', count3,
       'Stranger', count4,
       'Girlfriend',count5,
       'Ex-Husband', count6,
       'Brother', count7,
       'Stepdaughter', count8,
       'Husband', count9,
       'Sister',count10,
       'Friend', count11,
       'Family', count12,
       'Neighbor', count13,
       'Father', count14,
       'In-Law', count15,
       'Son',count16,
       'Ex-Wife', count17,
       'Boyfriend', count18,
       'Mother', count19,
       'Common-Law Husband',count20,
       'Common-Law Wife', count21,
       'Stepfather', count22,
       'Stepson', count23,
       'Stepmother',count24,
       'Daughter',count25,
       'Boyfriend/Girlfriend', count26,
       'Employer', count27,
       'Employee', count28)
# Out:
# Acquaintance 126018 Unknown 273013 Wife 23187 Stranger 96593 Girlfriend 16465 Ex-Husband 629 Brother 5514 Stepdaughter 754 Husband 8803 Sister 1292 Friend 21945 Family 9535 Neighbor 6294 Father 4361 In-Law 3637 Son 9904 Ex-Wife 1973 Boyfriend 7302 Mother 4248 Common-Law Husband 1954 Common-Law Wife 2477 Stepfather 1360 Stepson 1170 Stepmother 211 Daughter 7539 Boyfriend/Girlfriend 1383 Employer 509 Employee 384

# %%
Relationships = ('Wife','Friend','Girlfriend','Son','Family','Husband','Daughter',
                 'Boyfriend','Neighbor','Brother','Father','Mother','In-Law','Common-Law Wife ','Common-Law Husband','Ex-Wife ',
                 'Boyfriend/Girlfriend ','Stepfather','Sister','Stepson', 'Stepdaughter','Ex-Husband', 'Employer','Employee',
                 'Stepmother')
                 

scores = [23187, 21945, 16465,9904,9535,8803,7539,7302,6294,5514,4361,4248,3637,2477,1973,1954,1383,1360,1292,
         1170,754,629,509,384,211]


plt.bar(range(len(Relationships)), scores, alpha=0.4,)
plt.xticks(range(len(Relationships)), Relationships, rotation='vertical')
plt.title ('Number of Murder Cases VS Relationship')
plt.ylabel('Number of Murder Cases')
plt.xlabel('Relationship between perpetrator and victim')

# note: the most cases are Acquaintance-126018, Unknown-273013, Stranger-96593

# %%
whos
# Out:
# Variable             Type         Data/Info
# -------------------------------------------
# Relationship         DataFrame            Relationship\n0  <...>[638454 rows x 1 columns]
# Relationship_array   ndarray      1x638454: 638454 elems, type `int64`, 5107632 bytes (4.8710174560546875 Mb)
# a                    ndarray      6: 6 elems, type `int64`, 48 bytes
# count1               int          0
# df2                  DataFrame            Year  Relationshi<...>[638454 rows x 2 columns]
# i                    int64        25
# np                   module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# pd                   module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# relation             ndarray      638454: 638454 elems, type `int64`, 5107632 bytes (4.8710174560546875 Mb)
